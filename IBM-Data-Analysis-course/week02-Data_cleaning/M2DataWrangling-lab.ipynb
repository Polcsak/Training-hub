# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd
import requests

# %% [markdown]
# Load the dataset into a dataframe.

# %%
# URL of the CSV file
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv"


# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Save the content of the response to a file
    with open('survey_data.csv', 'wb') as f:
        f.write(response.content)
    
    
    
    print("CSV file downloaded and successfully.")
else:
    print("Failed to download CSV file.")
# Out:
# CSV file downloaded and successfully.

# %%
# Read the downloaded CSV file into a pandas DataFrame
df = pd.read_csv('survey_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11552 non-null  int64
#  1   MainBranch              11552 non-null  object
#  2   Hobbyist                11552 non-null  object
#  3   OpenSourcer             11552 non-null  object
#  4   OpenSource              11471 non-null  object
#  5   Employment              11552 non-null  object
#  6   Country                 11552 non-null  object
#  7   Student                 11499 non-null  object
#  8   EdLevel                 11436 non-null  object
#  9   UndergradMajor          10812 non-null  object
#  10  EduOther                11388 non-null  object
#  11  OrgSize                 11454 non-null  object
#  12  DevType                 11485 non-null  object
#  13  YearsCode               11543 non-null  object
# ...

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
num_duplicates = df.duplicated().sum()
num_duplicates
# Out:
# 154

# %%
df["CompFreq"].duplicated().sum()
# Out:
# 11548

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df_wo_duplicates = df.drop_duplicates()
df_wo_duplicates.shape
# Out:
# (11398, 85)

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here / same as fnc. duplicated()
print("Number of deleted rows is:",df.shape[0] - df_wo_duplicates.shape[0])
# Out:
# Number of deleted rows is: 154

# %%
df_wo_duplicates["CompFreq"].nunique()
# Out:
# 3

# %%
df_wo_duplicates[]

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
import numpy as np

# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
# your code goes here
missing_data = df_wo_duplicates.isnull().sum().sum()
missing_data
# Out:
# 30967

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
df_wo_duplicates["Country"].isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
new_df = pd.DataFrame(df_wo_duplicates["UndergradMajor"].value_counts())
new_df
# Out:
#                                                     count
# UndergradMajor
# Computer science, computer engineering, or soft...   6953
# Information systems, information technology, or...    794
# Another engineering discipline (ex. civil, elec...    759
# Web development or web design                         410
# A natural science (ex. biology, chemistry, phys...    403
# Mathematics or statistics                             372
# A business discipline (ex. accounting, finance,...    244
# A social science (ex. anthropology, psychology,...    210
# A humanities discipline (ex. literature, histor...    207
# Fine arts or performing arts (ex. graphic desig...    161
# I never declared a major                              124
# A health science (ex. nursing, pharmacy, radiol...     24

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference

df_wo_duplicates["WorkLoc"].value_counts().idxmax()
# Out:
# 'Office'

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
df_wo_missing = df_wo_duplicates["WorkLoc"].replace(np.nan, "Office")

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df_wo_duplicates["CompFreq"].value_counts()
# Out:
# CompFreq
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: count, dtype: int64

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %% [markdown]
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)

# %%
# your code goes here
NormalizedAnnualCompensation

df['NormalizedAnnualCompensation'] = df['length']/df['length'].max()

# %%
# Vytvorte nový stĺpec 'NormalizedAnnualCompensation'
df_wo_duplicates['NormalizedAnnualCompensation'] = df_wo_duplicates['CompTotal']

# Logika na získanie hodnôt pre stĺpec 'NormalizedAnnualCompensation'
# Ak je CompFreq 'Yearly', použite existujúcu hodnotu v CompTotal
# Ak je CompFreq 'Monthly', vynásobte hodnotu v CompTotal s 12 (mesiacov v roku)
# Ak je CompFreq 'Weekly', vynásobte hodnotu v CompTotal s 52 (týždňov v roku)
df_wo_duplicates.loc[df_wo_duplicates['CompFreq'] == 'Monthly', 'NormalizedAnnualCompensation'] *= 12
df_wo_duplicates.loc[df_wo_duplicates['CompFreq'] == 'Weekly', 'NormalizedAnnualCompensation'] *= 52

# Zobrazenie údajov
df_wo_duplicates[['CompFreq', 'CompTotal', 'NormalizedAnnualCompensation', "ConvertedComp", "CurrencySymbol"]]
# Out:
# C:\Users\jakub\AppData\Local\Temp\ipykernel_20808\1112750479.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wo_duplicates['NormalizedAnnualCompensation'] = df_wo_duplicates['CompTotal']
#       CompFreq  CompTotal  NormalizedAnnualCompensation  ConvertedComp  \
# 0       Yearly    61000.0                       61000.0        61000.0
# 1       Yearly   138000.0                      138000.0        95179.0
# 2       Yearly    90000.0                       90000.0        90000.0
# 3      Monthly    29000.0                      348000.0       455352.0
# 4       Yearly    90000.0                       90000.0        65277.0
# ...        ...        ...                           ...            ...
# ...

# %%
df_wo_duplicates["NormalizedAnnualCompensation"].median()
# Out:
# 100000.0

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
